# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('sber.csv',parse_dates=['date'])
df
# Out:
#                                                name               region  \
# 0      Количество заявок на потребительские кредиты               Россия
# 1      Количество заявок на потребительские кредиты               Россия
# 2      Количество заявок на потребительские кредиты               Россия
# 3      Количество заявок на потребительские кредиты               Россия
# 4      Количество заявок на потребительские кредиты               Россия
# ...                                             ...                  ...
# 74837                     Средние траты в ресторане  Ярославская область
# 74838                     Средние траты в ресторане  Ярославская область
# 74839                     Средние траты в ресторане  Ярославская область
# 74840                     Средние траты в ресторане  Ярославская область
# 74841                     Средние траты в ресторане  Ярославская область
#
#             date   value
# 0     2013-01-15  571147
# 1     2013-02-15  504508
# ...

# %%
from pprint import pprint

name = set(df.name)

#print(len(reg))
num = 0
data = {}
for n in name:
    num += 1
    data[num] = n
pprint (data)
n1 = int(input("Какие данные вы хотите посмотреть? Введите номер: "))
print (data[n1])
# Out:
# {1: 'Количество заявок на ипотечные кредиты',
#  2: 'Средний чек в формате Фастфуд',
#  3: 'Средняя сумма заявки на ипотечный кредит',
#  4: 'Средняя сумма заявки на потребительский кредит',
#  5: 'Средняя пенсия',
#  6: 'Количество заявок на потребительские кредиты',
#  7: 'Средняя зарплата',
#  8: 'Средний чек в формате Ресторан',
#  9: 'Средние траты в ресторане',
#  10: 'Средние расходы по картам',
#  11: 'Количество новых депозитов',
#  12: 'Средние траты в ресторане фастфуд',
#  13: 'В среднем руб. на текущем счете на человека',
#  14: 'В среднем депозитов в руб. на человека',
#  15: 'Средняя сумма нового депозита'}
# Какие данные вы хотите посмотреть? Введите номер: 5
# Средняя пенсия

# %%
df1 = df.loc[df.name==data[n1]]
#df1

# %%
reg = set(df.region)
#print(len(reg))
num = 0
data2 = {}
for r in reg:
    num += 1
    data2[num] = r
pprint (data2)
n2 = int(input("Введите номер региона: "))

print (data[n2])
# Out:
# {1: 'Ханты-Мансийский автономный округ — Югра',
#  2: 'Оренбургская область',
#  3: 'Республика Северная Осетия-Алания',
#  4: 'Санкт-Петербург',
#  5: 'Мурманская область',
#  6: 'Рязанская область',
#  7: 'Республика Башкортостан',
#  8: 'Самарская область',
#  9: 'Смоленская область',
#  10: 'Иркутская область',
#  11: 'Ленинградская область',
#  12: 'Республика Калмыкия',
#  13: 'Республика Тыва',
#  14: 'Ростовская область',
#  15: 'Москва',
#  16: 'Чувашская Республика',
#  17: 'Волгоградская область',
#  18: 'Пермский край',
#  19: 'Сахалинская область',
#  20: 'Чеченская Республика',
#  21: 'Красноярский край',
#  22: 'Забайкальский край',
#  23: 'Ульяновская область',
#  24: 'Кировская область',
#  25: 'Камчатский край',
#  26: 'Калужская область',
#  27: 'Ямало-Ненецкий автономный округ',
#  28: 'Республика Дагестан',
#  29: 'Московская область',
#  30: 'Псковская область',
#  31: 'Курская область',
#  32: 'Свердловская область',
#  33: 'Тамбовская область',
# ...

# %%
df2 = df1.loc[df1.region==data2[n2]]
#df2

# %%
# def data_ispr(dates):
#     yers={}
#     for date in dates:
#         date = str(date)[:4]
#         yers[date] = int(str(date)[:4])
#     yers = (sorted(set(yers)))
#     return yers
        

# # print(set(df2.date))   
# yers = data_ispr(set(df2.date))
# print((yers) +1)

# %%
from datetime import date
import matplotlib.dates
import pylab
# xdata = df2.date
# xdata_float=matplotlib.dates.date2num(xdata)
# xdata_float
# y = df2.value
# plt.plot(xdata_float,y)

# %%
pd.to_datetime(df.date)
# Out:
# 0       2013-01-15
# 1       2013-02-15
# 2       2013-03-15
# 3       2013-04-15
# 4       2013-05-15
#            ...
# 74837   2018-07-15
# 74838   2018-08-15
# 74839   2018-09-15
# 74840   2018-10-15
# 74841   2018-11-15
# Name: date, Length: 74842, dtype: datetime64[ns]

# %%
from pylab import rcParams
rcParams['figure.figsize']=17, 9
x = df2.date
y = df2.value
# plt.xticks(np.arange(min(yers), max(yers)+1,1.0))
plt.plot(x,y)
plt.show
# Out:
# C:\Users\poly0\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Добавление региона для сравнения

# %%
otvet1 = int(input("Вы хотите ввести регион для сравнения?\nДа-1/Нет-0 "))
# Out:
# Вы хотите ввести регион для сравнения?
# Да-1/Нет-0 1

# %%
if otvet1 == 1:
    pprint(data2)
    nom_new_reg = int(input("Введите номер региона: "))
    df3 = df1.loc[df1.region==data2[nom_new_reg]]
#     print(df3)
# Out:
# {1: 'Ханты-Мансийский автономный округ — Югра',
#  2: 'Оренбургская область',
#  3: 'Республика Северная Осетия-Алания',
#  4: 'Санкт-Петербург',
#  5: 'Мурманская область',
#  6: 'Рязанская область',
#  7: 'Республика Башкортостан',
#  8: 'Самарская область',
#  9: 'Смоленская область',
#  10: 'Иркутская область',
#  11: 'Ленинградская область',
#  12: 'Республика Калмыкия',
#  13: 'Республика Тыва',
#  14: 'Ростовская область',
#  15: 'Москва',
#  16: 'Чувашская Республика',
#  17: 'Волгоградская область',
#  18: 'Пермский край',
#  19: 'Сахалинская область',
#  20: 'Чеченская Республика',
#  21: 'Красноярский край',
#  22: 'Забайкальский край',
#  23: 'Ульяновская область',
#  24: 'Кировская область',
#  25: 'Камчатский край',
#  26: 'Калужская область',
#  27: 'Ямало-Ненецкий автономный округ',
#  28: 'Республика Дагестан',
#  29: 'Московская область',
#  30: 'Псковская область',
#  31: 'Курская область',
#  32: 'Свердловская область',
#  33: 'Тамбовская область',
# ...

# %%
x2 = df3.date
y2 = df3.value

# %%
pylab.plot(x,y)
pylab.plot(x2,y2)

# %%
plt.plot(x,y)
plt.plot(x2,y2)

# %%
otvet2 = int(input("Вы хотите посмотреть конкретный интервал по году?\nДа-1/Нет-0 "))
# Out:
# Вы хотите посмотреть конкретный интервал по году?
# Да-1/Нет-0 1

# %%
if otvet2 == 1:
    a = date(2013,9,8)
    b = date(2015,9,8)
#     Y1 = date(input("Введите левую границу: ")) #вручную ввод не получился
#     Y2 = date(int(input("Введите правую границу: ")))
    df4 = df3.loc[(df3.date>=a) & (df3.date<=b)]
    df5 = df2.loc[(df2.date>=a) & (df2.date<=b)]
#     df4 = df3.loc[(df3.date>=Y1) & (df3.date<=Y2)]
# Out:
# C:\Users\poly0\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#
# C:\Users\poly0\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   import sys

# %%
x = df5.date
y = df5.value
x2 = df4.date
y2 = df4.value

# %%
pylab.plot(x,y)
pylab.plot(x2,y2)
